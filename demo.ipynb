# %%
import polars as pl
import re

# %%
data=pl.read_parquet('/home/ming/NRMS/Data/small_news.parquet')

# %%
data.head()
# Out:
# shape: (5, 8)
# ┌─────────┬──────────┬────────────┬────────────┬────────────┬────────────┬────────────┬────────────┐
# │ news_id ┆ category ┆ subcategor ┆ title      ┆ abstract   ┆ url        ┆ title_enti ┆ abstract_e │
# │ ---     ┆ ---      ┆ y          ┆ ---        ┆ ---        ┆ ---        ┆ ties       ┆ ntities    │
# │ str     ┆ str      ┆ ---        ┆ str        ┆ str        ┆ str        ┆ ---        ┆ ---        │
# │         ┆          ┆ str        ┆            ┆            ┆            ┆ list[struc ┆ list[struc │
# │         ┆          ┆            ┆            ┆            ┆            ┆ t[6]]      ┆ t[6]]      │
# ╞═════════╪══════════╪════════════╪════════════╪════════════╪════════════╪════════════╪════════════╡
# │ N38974  ┆ sports   ┆ football_n ┆ David      ┆ One can    ┆ https://as ┆ [{"David   ┆ [{"David   │
# │         ┆          ┆ fl         ┆ Bakhtiari  ┆ only       ┆ sets.msn.c ┆ Bakhtiari" ┆ Bakhtiari" │
# ...

# %%
data=data.with_columns(pl.col('title'))
